# %%
# %load_ext sql

# %%
# %sql postgresql://appdev@data/appdev
# Out:
# 'Connected: appdev@appdev'

# %% [markdown]
# 1. On the table "circuits" report:
#     * What type of indices exists for the table and why they are of that type (and not some other type)
#
#       The table circuits contains three types of indices:
#     - circuitid which is a primary key in the form of a btree. The btree has the search algorithm of O(log(n)). The reason this is used is because when it comes to big data structures it iterates fewer times and therefor a shorter execution time 'O'.
#
#      - url which is uniqe and in the form of a btree aswell.
#
#      - position is a gist. The position is based on a box value (x1, y1),(x2, y2) this takes to point values(x,y) and this is where the gist comes in, as gist is based on a <key, pointer> ergo <position, circuits_position_idx>.
#
#     * The amount of space each index takes up

# %%
# %sql SELECT * FROM pg_indexes WHERE tablename = 'circuits';
# Out:
# 3 rows affected.
# [('f1db', 'circuits', 'idx_17102_url', None, 'CREATE UNIQUE INDEX idx_17102_url ON circuits USING btree (url)'),
#  ('f1db', 'circuits', 'circuits_position_idx', None, 'CREATE INDEX circuits_position_idx ON circuits USING gist ("position")'),
#  ('f1db', 'circuits', 'idx_17102_primary', None, 'CREATE UNIQUE INDEX idx_17102_primary ON circuits USING btree (circuitid)')]

# %% [markdown]
#  2. We are talent scouts looking to win over some of the best new drivers there are. But we don't want them too old! Write a query that finds the winner of all the races, but only if they are younger than 38 years. The query should give return the date, driver surname, driver age, track time in milliseconds, race name and circuit name for all races.

# %%
# %sql SELECT races.date, drivers.surname, drivers.dob, results.milliseconds, races.name, circuits.name FROM results JOIN races ON results.raceid = races.raceid JOIN drivers ON results.driverid = drivers.driverid JOIN circuits ON races.circuitid = circuits.circuitid WHERE results.position = 1 AND drivers.dob >= '1980.03.20' ORDER BY date;
# Out:
# 184 rows affected.
# [(datetime.date(2003, 8, 24), 'Alonso', datetime.date(1981, 7, 29), 5941460, 'Hungarian Grand Prix', 'Hungaroring'),
#  (datetime.date(2005, 3, 20), 'Alonso', datetime.date(1981, 7, 29), 5493736, 'Malaysian Grand Prix', 'Sepang International Circuit'),
#  (datetime.date(2005, 4, 3), 'Alonso', datetime.date(1981, 7, 29), 5358531, 'Bahrain Grand Prix', 'Bahrain International Circuit'),
#  (datetime.date(2005, 4, 24), 'Alonso', datetime.date(1981, 7, 29), 5261921, 'San Marino Grand Prix', 'Autodromo Enzo e Dino Ferrari'),
#  (datetime.date(2005, 5, 29), 'Alonso', datetime.date(1981, 7, 29), 5506648, 'European Grand Prix', 'Nürburgring'),
#  (datetime.date(2005, 7, 3), 'Alonso', datetime.date(1981, 7, 29), 5482232, 'French Grand Prix', 'Circuit de Nevers Magny-Cours'),
#  (datetime.date(2005, 7, 24), 'Alonso', datetime.date(1981, 7, 29), 5188599, 'German Grand Prix', 'Hockenheimring'),
# ...

# %% [markdown]
# 3. Describe the query using ``EXPLAIN ANALYZE`` with at least 5 lines of text. Answer at least the following:
#     *How many calls are you making?
#     *How long does it take to perform the query?
#     In planning time it took 1.926 ms and in execution time it took 16.597 ms, so it took in total 18.523 ms.

# %%
# %sql EXPLAIN ANALYZE SELECT races.date, drivers.surname, drivers.dob, results.milliseconds, races.name, circuits.name FROM results JOIN races ON results.raceid = races.raceid JOIN drivers ON results.driverid = drivers.driverid JOIN circuits ON races.circuitid = circuits.circuitid WHERE results.position = 1 AND drivers.dob >= '1980.03.20' ORDER BY date;
# Out:
# 21 rows affected.
# [('Sort  (cost=786.85..787.02 rows=68 width=62) (actual time=16.351..16.386 rows=184 loops=1)',),
#  ('  Sort Key: races.date',),
#  ('  Sort Method: quicksort  Memory: 50kB',),
#  ('  ->  Nested Loop  (cost=25.67..784.78 rows=68 width=62) (actual time=0.696..16.022 rows=184 loops=1)',),
#  ('        ->  Nested Loop  (cost=25.53..772.81 rows=68 width=50) (actual time=0.675..14.889 rows=184 loops=1)',),
#  ('              ->  Hash Join  (cost=25.25..746.50 rows=68 width=27) (actual time=0.639..13.158 rows=184 loops=1)',),
#  ('                    Hash Cond: (results.driverid = drivers.driverid)',),
#  ('                    ->  Seq Scan on results  (cost=0.00..708.96 rows=974 width=24) (actual time=0.027..11.811 rows=974 loops=1)',),
#  ('                          Filter: ("position" = 1)',),
#  ('                          Rows Removed by Filter: 22703',),
# ...
